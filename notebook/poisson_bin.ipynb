# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from eda_package import *

# %%
pipeline= SimpleModelPipeline()

# %%
results = pipeline.run()
# Out:
# /Users/beza/.pyenv/versions/3.10.6/envs/noshowshield/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/beza/.pyenv/versions/3.10.6/envs/noshowshield/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
probs = results["probabilities"][:50]

# %%
analysis = pipeline.analyze_no_show_risk(probs, threshold_k=10)

# %%
print(analysis)
# Out:
# {'expected_no_shows': 16.317449769354493, 'variance': 10.183361151169851, 'prob_at_least_k': 0.9866317438011523}

# %%
pipeline.save_model("simple_logistic_model")
# Out:
# Model saved to: /Users/beza/code/bezawitzyb/noshowshield/models/simple_logistic_model_20260318_125433.joblib
# '/Users/beza/code/bezawitzyb/noshowshield/models/simple_logistic_model_20260318_125433.joblib'
