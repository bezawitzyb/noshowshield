# %% [markdown]
# ## Loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = '../raw_data/hotel_bookings.csv'

data = pd.read_csv(url)
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ## Duplicate analysis

# %%
duplicate_count = data.duplicated().sum()
duplicate_count
# Out:
# np.int64(31994)

# %%
data[data.duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87392 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %% [markdown]
# ## Missing data analysis

# %%
print(data.isnull().mean().sort_values(ascending=False))
# Out:
# company                           0.939826
# agent                             0.139514
# country                           0.005172
# children                          0.000046
# arrival_date_month                0.000000
# arrival_date_week_number          0.000000
# hotel                             0.000000
# is_canceled                       0.000000
# stays_in_weekend_nights           0.000000
# arrival_date_day_of_month         0.000000
# adults                            0.000000
# stays_in_week_nights              0.000000
# babies                            0.000000
# meal                              0.000000
# lead_time                         0.000000
# arrival_date_year                 0.000000
# distribution_channel              0.000000
# market_segment                    0.000000
# previous_bookings_not_canceled    0.000000
# is_repeated_guest                 0.000000
# reserved_room_type                0.000000
# assigned_room_type                0.000000
# ...

# %%
print(data.isnull().sum().sort_values(ascending=False))
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# arrival_date_month                    0
# arrival_date_week_number              0
# hotel                                 0
# is_canceled                           0
# stays_in_weekend_nights               0
# arrival_date_day_of_month             0
# adults                                0
# stays_in_week_nights                  0
# babies                                0
# meal                                  0
# lead_time                             0
# arrival_date_year                     0
# distribution_channel                  0
# market_segment                        0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# ...

# %% [markdown]
# ### Company

# %%
len(data['company'].unique())
# Out:
# 353

# %%
data[data['company'].notnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 18      Resort Hotel            0          0               2015
# 218     Resort Hotel            1          1               2015
# 220     Resort Hotel            0          1               2015
# 295     Resort Hotel            0         84               2015
# 387     Resort Hotel            0          1               2015
# ...              ...          ...        ...                ...
# 119117    City Hotel            0         39               2017
# 119118    City Hotel            0          1               2017
# 119119    City Hotel            0         40               2017
# 119124    City Hotel            0          0               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 18                   July                        27
# 218                  July                        28
# ...

# %%
data[data['company']==0]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 32 columns]

# %%
data['company'] = data.company.replace(np.nan, 0)

# %% [markdown]
# ### Agent

# %%
data.shape
# Out:
# (87396, 32)

# %%
data['agent'].unique()
# Out:
# array([ nan, 304., 240., 303.,  15., 241.,   8., 250., 115.,   5., 175.,
#        134., 156., 243., 242.,   3., 105.,  40., 147., 306., 184.,  96.,
#          2., 127.,  95., 146.,   9., 177.,   6., 143., 244., 149., 167.,
#        300., 171., 305.,  67., 196., 152., 142., 261., 104.,  36.,  26.,
#         29., 258., 110.,  71., 181.,  88., 251., 275.,  69., 248., 208.,
#        256., 314., 126., 281., 273., 253., 185., 330., 334., 328., 326.,
#        321., 324., 313.,  38., 155.,  68., 335., 308., 332.,  94., 348.,
#        310., 339., 375.,  66., 327., 387., 298.,  91., 245., 385., 257.,
#        393., 168., 405., 249., 315.,  75., 128., 307.,  11., 436.,   1.,
#        201., 183., 223., 368., 336., 291., 464., 411., 481.,  10., 154.,
#        468., 410., 390., 440., 495., 492., 493., 434.,  57., 531., 420.,
#        483., 526., 472., 429.,  16., 446.,  34.,  78., 139., 252., 270.,
#         47., 114., 301., 193., 182., 135., 350., 195., 352., 355., 159.,
# ...

# %%
print('Number of unique agents: ', len(data['agent'].unique()))
print('Number of entries with agent: ', data.shape[0] - data['agent'].isnull().sum())
print('Number of entries without agent: ', data['agent'].isnull().sum())
# Out:
# Number of unique agents:  334
# Number of entries with agent:  75203
# Number of entries without agent:  12193

# %%
data[data['agent']==0]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 32 columns]

# %%
data['agent'] = data.agent.replace(np.nan, 0)

# %% [markdown]
# ### Country

# %%
data['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', nan, 'ROU', 'NOR', 'OMN',
#        'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA', 'NLD',
#        'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN', 'MOZ',
#        'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR', 'UKR',
#        'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU', 'TUR',
#        'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA', 'KOR',
#        'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN', 'GEO',
#        'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY', 'KWT',
#        'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN', 'LBN',
#        'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM', 'MKD',
#        'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS', 'COM',
#        'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI', 'SAU',
#        'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU', 'MDG',
# ...

# %%
data['country'] = data['country'].replace(np.nan, 'None')
data['country'].unique()
# Out:
# array(['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', 'None', 'ROU', 'NOR',
#        'OMN', 'ARG', 'POL', 'DEU', 'BEL', 'CHE', 'CN', 'GRC', 'ITA',
#        'NLD', 'DNK', 'RUS', 'SWE', 'AUS', 'EST', 'CZE', 'BRA', 'FIN',
#        'MOZ', 'BWA', 'LUX', 'SVN', 'ALB', 'IND', 'CHN', 'MEX', 'MAR',
#        'UKR', 'SMR', 'LVA', 'PRI', 'SRB', 'CHL', 'AUT', 'BLR', 'LTU',
#        'TUR', 'ZAF', 'AGO', 'ISR', 'CYM', 'ZMB', 'CPV', 'ZWE', 'DZA',
#        'KOR', 'CRI', 'HUN', 'ARE', 'TUN', 'JAM', 'HRV', 'HKG', 'IRN',
#        'GEO', 'AND', 'GIB', 'URY', 'JEY', 'CAF', 'CYP', 'COL', 'GGY',
#        'KWT', 'NGA', 'MDV', 'VEN', 'SVK', 'FJI', 'KAZ', 'PAK', 'IDN',
#        'LBN', 'PHL', 'SEN', 'SYC', 'AZE', 'BHR', 'NZL', 'THA', 'DOM',
#        'MKD', 'MYS', 'ARM', 'JPN', 'LKA', 'CUB', 'CMR', 'BIH', 'MUS',
#        'COM', 'SUR', 'UGA', 'BGR', 'CIV', 'JOR', 'SYR', 'SGP', 'BDI',
#        'SAU', 'VNM', 'PLW', 'QAT', 'EGY', 'PER', 'MLT', 'MWI', 'ECU',
# ...

# %% [markdown]
# ### Children

# %%
data['children'].unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
data['children'].value_counts()
# Out:
# children
# 0.0     79028
# 1.0      4695
# 2.0      3593
# 3.0        75
# 10.0        1
# Name: count, dtype: int64

# %%
data['children'] = data['children'].replace(np.nan, 0)

# %% [markdown]
# ## Categorical features

# %%
feat_categorical_nunique = data.select_dtypes(include=['object']).nunique().sort_values(ascending=False)
print(feat_categorical_nunique.sum())
feat_categorical_nunique
# Out:
# 1168
# reservation_status_date    926
# country                    178
# assigned_room_type          12
# arrival_date_month          12
# reserved_room_type          10
# market_segment               8
# distribution_channel         5
# meal                         5
# customer_type                4
# deposit_type                 3
# reservation_status           3
# hotel                        2
# dtype: int64

# %%
def group_countries(
    data:pd.DataFrame,
    limit:int
    )-> pd.DataFrame:

    country_counts = data['country'].value_counts()
    countries_included = country_counts[country_counts >= limit].index

    data['country_group'] = data['country'].apply(
        lambda x: x if x in countries_included else 'Other'
    )
    return data

# %%
df = group_countries(data=data, limit=50)
df.groupby('country_group')['is_canceled'].mean()
# Out:
# country_group
# AGO      0.564327
# ARG      0.251232
# AUS      0.243386
# AUT      0.179514
# BEL      0.197501
# BGR      0.132353
# BRA      0.364411
# CHE      0.244586
# CHL      0.246154
# CHN      0.480392
# CN       0.205855
# COL      0.333333
# CZE      0.242647
# DEU      0.195471
# DNK      0.236979
# DZA      0.256098
# ESP      0.256757
# EST      0.227848
# FIN      0.151659
# FRA      0.196107
# GBR      0.190262
# GRC      0.282051
# HRV      0.252747
# HUN      0.321782
# IND      0.237762
# IRL      0.221485
# IRN      0.275000
# ISR      0.330025
# ITA      0.350620
# JPN      0.136612
# KOR      0.361345
# LTU      0.095890
# LUX      0.393130
# LVA      0.156863
# MAR      0.448276
# MEX      0.121622
# MOZ      0.303571
# NLD      0.183150
# NOR      0.281553
# NZL      0.063492
# None     0.075221
# Other    0.379257
# POL      0.214379
# PRT      0.356646
# ROU      0.257642
# RUS      0.395722
# SRB      0.055556
# SWE      0.211470
# TUR      0.455399
# ...

# %%
data['reserved_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'H', 'L', 'P', 'B'], dtype=object)

# %%
data['assigned_room_type'].unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'I', 'B', 'H', 'P', 'L', 'K'],
#       dtype=object)

# %%
data['reservation_status'].unique()
# Out:
# array(['Check-Out', 'Canceled', 'No-Show'], dtype=object)

# %% [markdown]
# ## Numerical features

# %%
numeric_df = data.select_dtypes('number')
corr_matrix = numeric_df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='YlOrBr', fmt=".2f")
plt.show()

# %% [markdown]
# ## Feature selection

# %%
plt.figure(figsize=(8,5))
plt.hist(data['country']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plt.figure(figsize=(8,5))
#       2 plt.hist(data['country']);
#
# NameError: name 'plt' is not defined

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from eda_package.data import load_raw_data, clean_data, temporal_split_v2, temporal_split, split_X_y
from eda_package.features import engineer_features
from eda_package.preprocessor import (
    group_countries,
    get_feature_lists,
    create_preprocessor,
    fit_transform_preprocessor,
    preprocess_pipeline,
    transform_preprocessor
)
from eda_package.registry import ORDINAL_FEATURES_MAP, COUNTRY_LIMIT

df = load_raw_data()
df = clean_data(df)

#SHOULD WE MOVE THIS TO FEATURES OR DATA?
df = group_countries(df, COUNTRY_LIMIT)

df = engineer_features(df)


#training_set, test_set = temporal_split_v2(df, 2017, 5)
training_set, test_set = temporal_split(df, 2017)

#print(training_set.groupby(['arrival_date_year', 'arrival_date_month']).size())
#print(test_set.groupby(['arrival_date_year', 'arrival_date_month']).size())

X_train, y_train= split_X_y(training_set)
X_test, y_test= split_X_y(test_set)

X_train_processed, X_test_processed = preprocess_pipeline(X_train, X_test)

#feature_lists = get_feature_lists(X_train, ORDINAL_FEATURES_MAP)
#preprocessor = create_preprocessor(feature_lists, ORDINAL_FEATURES_MAP)
#X_train_processed = fit_transform_preprocessor(X_train, preprocessor)
#X_test_processed = transform_preprocessor(X_test, preprocessor)

# %%
print(y_train.value_counts())
print(y_test.value_counts())
disbalance_ratio_train = y_train.value_counts()[0]/y_train.value_counts()[1]
disbalance_ratio_test = y_test.value_counts()[0]/y_test.value_counts()[1]

print(disbalance_ratio_train, disbalance_ratio_test)
# Out:
# 0    41792
# 1    13912
# Name: is_canceled, dtype: int64
# 0    21579
# 1    10113
# Name: is_canceled, dtype: int64
# 3.0040253018976424 2.133788193414417

# %%
plt.hist(y_train);

# %%
X_train_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61840 entries, 0 to 107072
# Columns: 305 entries, num__lead_time to cat_ordinal__meal
# dtypes: float64(305)
# memory usage: 144.4 MB

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model = LogisticRegression(max_iter=10000)
model.fit(X_train_processed, y_train)
y_predicted = model.predict(X_test_processed)

print(f'Accuracy: {round(accuracy_score(y_test, y_predicted),2)}')
print(f'Recall: {round(recall_score(y_test, y_predicted),2)}')
print(f'Precision: {round(precision_score(y_test, y_predicted),2)}')
print(f'F1 score: {round(f1_score(y_test, y_predicted),2)}')
# Out:
# Accuracy: 0.75
# Recall: 0.65
# Precision: 0.6
# F1 score: 0.63

# %%
# %load_ext autoreload
# %autoreload 2

from eda_package.model import the_brain

the_brain()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Accuracy: 0.75
# Recall: 0.66
# Precision: 0.62
# F1 score: 0.64
# /home/bbedic/.pyenv/versions/3.10.6/envs/noshowshield/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

#model = LogisticRegression(max_iter=10000)
model = SVC(kernel='linear', C=1, verbose=True)

model.fit(X_train_processed, y_train)
y_predicted = model.predict(X_test_processed)

print(f'Accuracy: {round(accuracy_score(y_test, y_predicted),2)}')
print(f'Recall: {round(recall_score(y_test, y_predicted),2)}')
print(f'Precision: {round(precision_score(y_test, y_predicted),2)}')
print(f'F1 score: {round(f1_score(y_test, y_predicted),2)}')
# Out:
# [LibSVM]..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

xgb = XGBClassifier(objective='binary:logistic', random_state=0)

params_dict={'n_estimators': [100,300,500],
    'max_depth': [3, 6, 10],
    'gamma': [0.5, 1, 2, 5, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'scale_pos_weight': [1,3],
}
grid_model = GridSearchCV(
    xgb,
    param_grid=params_dict,
    scoring='f1',
    cv=5,
    n_jobs=-1
    )

grid_model.fit(X_train_processed,y_train, verbose=True)
best_core_params=grid_model.best_params_
print(best_core_params)

estimator= XGBClassifier(**best_core_params)
estimator.fit(X_train_processed,y_train)
y_predicted=estimator.predict(X_test_processed)

print(f'Accuracy: {round(accuracy_score(y_test, y_predicted),2)}')
print(f'Recall: {round(recall_score(y_test, y_predicted),2)}')
print(f'Precision: {round(precision_score(y_test, y_predicted),2)}')
print(f'F1 score: {round(f1_score(y_test, y_predicted),2)}')
# Out:
# {'gamma': 10, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100}
# Accuracy: 0.78
# Recall: 0.49
# Precision: 0.72
# F1 score: 0.58

# %%
probs = estimator.predict_proba(X_test_processed)
probs_cancelled = probs[:, 1]
y_updated = (probs_cancelled > 0.3).astype(int)
y_updated
print(f'Accuracy: {round(accuracy_score(y_test, y_updated),2)}')
print(f'Recall: {round(recall_score(y_test, y_updated),2)}')
print(f'Precision: {round(precision_score(y_test, y_updated),2)}')
print(f'F1 score: {round(f1_score(y_test, y_updated),2)}')
# Out:
# Accuracy: 0.74
# Recall: 0.58
# Precision: 0.61
# F1 score: 0.6

# %%
from sklearn.metrics import classification_report

#estimator= grid_model.best_estimator_

estimator2 = XGBClassifier(
    objective='binary:logistic',
    random_state=0,
    gamma=5,
    n_estimators=300,
    learning_rate=0.1,
    max_depth=10)
estimator2.fit(X_train_processed,y_train)

y_predicted=estimator2.predict(X_test_processed)

print(f'Accuracy: {round(accuracy_score(y_test, y_predicted),2)}')
print(f'Recall: {round(recall_score(y_test, y_predicted),2)}')
print(f'Precision: {round(precision_score(y_test, y_predicted),2)}')
print(f'F1 score: {round(f1_score(y_test, y_predicted),2)}')
print(classification_report(y_test,y_predicted))
# Out:
# predict accuracy：0.7816799192225167
# Accuracy: 0.78
# Recall: 0.5
# Precision: 0.73
# F1 score: 0.59
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85     21579
#            1       0.73      0.50      0.59     10113
#
#     accuracy                           0.78     31692
#    macro avg       0.76      0.71      0.72     31692
# weighted avg       0.78      0.78      0.77     31692

# %%
from sklearn.metrics import classification_report

#estimator= grid_model.best_estimator_

estimator2 = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    random_state=0,
    gamma=5,
    n_estimators=300,
    learning_rate=0.1,
    max_depth=10)
estimator2.fit(X_train_processed,y_train)

y_predicted=estimator2.predict(X_test_processed)

print(f'Accuracy: {round(accuracy_score(y_test, y_predicted),2)}')
print(f'Recall: {round(recall_score(y_test, y_predicted),2)}')
print(f'Precision: {round(precision_score(y_test, y_predicted),2)}')
print(f'F1 score: {round(f1_score(y_test, y_predicted),2)}')
print(classification_report(y_test,y_predicted))
# Out:
# predict accuracy：0.7816799192225167
# Accuracy: 0.78
# Recall: 0.5
# Precision: 0.73
# F1 score: 0.59
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85     21579
#            1       0.73      0.50      0.59     10113
#
#     accuracy                           0.78     31692
#    macro avg       0.76      0.71      0.72     31692
# weighted avg       0.78      0.78      0.77     31692

# %%
from eda_package.model import BookingPredictor

predictor = BookingPredictor(X_train_processed=X_train_processed, y_train=y_train)
predictor.test(X_test_processed, y_test)
predictor.save_model()

predictor2 = BookingPredictor()
predictor2.test(X_test_processed, y_test)
file_name = 'some_file_name.pkl'
predictor2.save_model(file_name)

predictor3 = BookingPredictor(file_name=file_name)
predictor3.test(X_test_processed, y_test)
# Out:
# Testing <class 'xgboost.sklearn.XGBClassifier'>
# Accuracy: 0.77
# Recall: 0.72
# Precision: 0.62
# F1 score: 0.67
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82     21579
#            1       0.62      0.72      0.67     10113
#
#     accuracy                           0.77     31692
#    macro avg       0.74      0.76      0.75     31692
# weighted avg       0.78      0.77      0.77     31692
#
# Testing <class 'xgboost.sklearn.XGBClassifier'>
# Accuracy: 0.77
# Recall: 0.72
# Precision: 0.62
# F1 score: 0.67
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82     21579
#            1       0.62      0.72      0.67     10113
#
#     accuracy                           0.77     31692
#    macro avg       0.74      0.76      0.75     31692
# weighted avg       0.78      0.77      0.77     31692
#
# Testing <class 'xgboost.sklearn.XGBClassifier'>
# Accuracy: 0.77
# Recall: 0.72
# ...

# %%
#{'gamma': 10, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100}
final_params = {
    'n_estimators': 100, #100, 300
    'max_depth': 3, #3, 10
    'learning_rate': 0.2, #0.2, 0.05
    'gamma': 10, #10, 1
#    'lambda': 1,
#    'alpha': 0,
    'subsample': 0.5, #minimal impact
    'colsample_bytree': 0.3, #minimal impact
    'min_child_weight': 2, #minimal impact
    'random_state': 0,
    'scale_pos_weight': disbalance_ratio_train, #impact
    'eval_metric': 'logloss'
}
estimator3=XGBClassifier(**final_params)
estimator3.fit(X_train_processed,y_train)
y_pre=estimator3.predict(X_test_processed)

print(f'Accuracy: {round(accuracy_score(y_test, y_pre),2)}')
print(f'Recall: {round(recall_score(y_test, y_pre),2)}')
print(f'Precision: {round(precision_score(y_test, y_pre),2)}')
print(f'F1 score: {round(f1_score(y_test, y_pre),2)}')
print(classification_report(y_test,y_pre))

"""
Accuracy: 0.78
Recall: 0.68
Precision: 0.66
F1 score: 0.67
"""
# Out:
# Accuracy: 0.77
# Recall: 0.72
# Precision: 0.62
# F1 score: 0.67
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82     21579
#            1       0.62      0.72      0.67     10113
#
#     accuracy                           0.77     31692
#    macro avg       0.74      0.76      0.75     31692
# weighted avg       0.78      0.77      0.77     31692
# '\nAccuracy: 0.78\nRecall: 0.68\nPrecision: 0.66\nF1 score: 0.67\n'

# %% [markdown]
# ## Neural network

# %%
from keras import Sequential, Input, layers


def initialize_model():
    model = Sequential()

    model.add(Input(shape=(X_train_processed.shape[-1],)))
    model.add(layers.Dense(500, activation='relu'))
    model.add(layers.Dense(300, activation='relu'))
    model.add(layers.Dense(100, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model

# %%
from keras.callbacks import EarlyStopping

model = initialize_model()
es = EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(
    X_train_processed,
    y_train,
    batch_size=32,
    epochs=100,
    validation_split=0.2,
    callbacks=[es],
    shuffle=True,
    verbose=1)
# Out:
# Epoch 1/100
# 1393/1393 [==============================] - 7s 5ms/step - loss: 0.3346 - accuracy: 0.8582 - val_loss: 2.6018 - val_accuracy: 0.2897
# Epoch 2/100
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.2712 - accuracy: 0.8815 - val_loss: 2.2079 - val_accuracy: 0.3711
# Epoch 3/100
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.2556 - accuracy: 0.8911 - val_loss: 3.3008 - val_accuracy: 0.3036
# Epoch 4/100
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.2445 - accuracy: 0.8933 - val_loss: 5.0892 - val_accuracy: 0.2348
# Epoch 5/100
# 1393/1393 [==============================] - 5s 4ms/step - loss: 0.2346 - accuracy: 0.8986 - val_loss: 4.5006 - val_accuracy: 0.2675
# Epoch 6/100
# 1393/1393 [==============================] - 6s 4ms/step - loss: 0.2266 - accuracy: 0.9011 - val_loss: 8.8342 - val_accuracy: 0.1841
# Epoch 7/100
# ...

# %%
results = model.evaluate(X_test_processed, y_test)
results
# Out:
# 991/991 [==============================] - 2s 2ms/step - loss: 1.6269 - accuracy: 0.6310
# [1.6269422769546509, 0.6309794187545776]

# %%
y_prediction = model.predict(X_test_processed)
y_pred = (y_prediction[:,0] > 0.5).astype(int)
print(f'Accuracy: {round(accuracy_score(y_test, y_pred),2)}')
print(f'Recall: {round(recall_score(y_test, y_pred),2)}')
print(f'Precision: {round(precision_score(y_test, y_pred),2)}')
print(f'F1 score: {round(f1_score(y_test, y_pred),2)}')
# Out:
# 991/991 [==============================] - 2s 2ms/step
# Accuracy: 0.63
# Recall: 0.81
# Precision: 0.46
# F1 score: 0.58
