# %%
#make imports from package available at top level for ease of use
from eda_package.optimiser import OverbookingOptimizer

# Pre-warm recommendations cache with default parameters
print("Pre-warming recommendations cache...")
default_optimizer = OverbookingOptimizer()
default_key = (
    default_optimizer.relocation_cost,
    default_optimizer.max_risk,
    default_optimizer.max_extra_sweep,
)

optimisation_cache[default_key] = default_optimizer.aggregate_and_recommend(
    raw_df=X_test_with_dates,
    cancel_probs=cancel_probs,
    capacity_map=capacity_map,
)

print("Optimisation cache ready")
print(optimisation_cache.keys())
# Out:
# Pre-warming recommendations cache...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 14
#       6 default_optimizer = OverbookingOptimizer()
#       7 default_key = (
#       8     default_optimizer.relocation_cost,
#       9     default_optimizer.max_risk,
#      10     default_optimizer.max_extra_sweep,
#      11 )
#      13 optimisation_cache[default_key] = default_optimizer.aggregate_and_recommend(
# ---> 14     raw_df=X_test_with_dates,
#      15     cancel_probs=cancel_probs,
#      16     capacity_map=capacity_map,
#      17 )
#      19 print("Optimisation cache ready")
#      20 print(optimisation_cache.keys())
#
# NameError: name 'X_test_with_dates' is not defined
