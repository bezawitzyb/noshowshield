# %%
from eda_package.model import build_pipeline, train_model
from eda_package import *

# %%
pipe = build_pipeline()

# %%
pipe
# Out:
# Pipeline(steps=[('preprocessor', None), ('model', LogisticRegression())])

# %%
train_model(pipe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_93656/1770028955.py in ?()
# ----> 1 train_model(pipe)
#
# ~/code/bezawitzyb/noshowshield/eda_package/model.py in ?(pipeline)
#      57     # Set the preprocessor in the pipeline
#      58     pipeline.named_steps['preprocessor'] = preprocessor
#      59
#      60     # Fit the pipeline
# ---> 61     pipeline.fit(X_full_train, y_full_train)
#      62     return pipeline
#
# ~/.pyenv/versions/noshowshield/lib/python3.10/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
    # Prepare the data as in the_brain
    from sklearn import pipeline


df = load_raw_data()
    df = clean_data(df)
    df = group_countries(df, COUNTRY_LIMIT)
    df = engineer_features(df)
    training_set, _ = temporal_split(df, '2017-03-01')
    X_full_train, y_full_train = split_X_y(training_set)

    # # Get feature lists from full training data
    feature_lists = get_feature_lists(X_full_train, ORDINAL_FEATURES_MAP)
    preprocessor = create_preprocessor(feature_lists, ORDINAL_FEATURES_MAP)

    # # Set the preprocessor in the pipeline
    pipe.named_steps['preprocessor'] = preprocessor

    # # Fit the pipeline
    pipe.fit(X_full_train, y_full_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_93656/3215163097.py in ?()
#      16 # # Set the preprocessor in the pipeline
#      17 pipe.named_steps['preprocessor'] = preprocessor
#      18
#      19 # # Fit the pipeline
# ---> 20 pipe.fit(X_full_train, y_full_train)
#
# ~/.pyenv/versions/noshowshield/lib/python3.10/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# ~/.pyenv/versions/noshowshield/lib/python3.10/site-packages/sklearn/pipeline.py in ?(self, X, y, **fit_params)
#     423         Xt = self._fit(X, y, **fit_params_steps)
# ...
